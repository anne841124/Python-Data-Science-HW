# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange'] * 3,
    'weight': ['high', 'medium', 'low'] * 3,
    'price': np.random.randint(0, 15, 9)
})

df2 = pd.DataFrame({
    'fruit': ['apple', 'orange', 'pine'] * 2,
    'weight': ['high', 'low'] * 3,
    'price': np.random.randint(0, 15, 6)
})
print(df1)
print(df2)
# Out:
#     fruit  weight  price
# 0   apple    high     13
# 1  banana  medium      2
# 2  orange     low     14
# 3   apple    high     10
# 4  banana  medium     10
# 5  orange     low      2
# 6   apple    high      0
# 7  banana  medium     13
# 8  orange     low      3
#     fruit weight  price
# 0   apple   high      7
# 1  orange    low      7
# 2    pine   high      4
# 3   apple    low     10
# 4  orange   high      6
# 5    pine    low     13

# %%
pd.merge(df1, df2, on = 'fruit')
# Out:
#      fruit weight_x  price_x weight_y  price_y
# 0    apple     high       13     high        7
# 1    apple     high       13      low       10
# 2    apple     high       10     high        7
# 3    apple     high       10      low       10
# 4    apple     high        0     high        7
# 5    apple     high        0      low       10
# 6   orange      low       14      low        7
# 7   orange      low       14     high        6
# 8   orange      low        2      low        7
# 9   orange      low        2     high        6
# 10  orange      low        3      low        7
# 11  orange      low        3     high        6

# %%
pd.concat([df1, df2]).reset_index(drop = True)
# Out:
#      fruit  weight  price
# 0    apple    high     13
# 1   banana  medium      2
# 2   orange     low     14
# 3    apple    high     10
# 4   banana  medium     10
# 5   orange     low      2
# 6    apple    high      0
# 7   banana  medium     13
# 8   orange     low      3
# 9    apple    high      7
# 10  orange     low      7
# 11    pine    high      4
# 12   apple     low     10
# 13  orange    high      6
# 14    pine     low     13

# %%
pd.merge(df1, df2, on = 'index')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-fc073f7769e4> in <module>
# ----> 1 pd.merge(df1, df2, on = 'index')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1031                     if not is_rkey(rk):
#    1032                         if rk is not None:
# -> 1033                             right_keys.append(right._get_label_or_level_values(rk))
#    1034                         else:
#    1035                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'index'

# %%
#因為merge合併相同資料，兩者之間資料有差距

#因為index數量不同

# %%
pd.merge(df1, df2, left_index = True, right_index = True)
# Out:
#   fruit_x weight_x  price_x fruit_y weight_y  price_y
# 0   apple     high       13   apple     high        7
# 1  banana   medium        2  orange      low        7
# 2  orange      low       14    pine     high        4
# 3   apple     high       10   apple      low       10
# 4  banana   medium       10  orange     high        6
# 5  orange      low        2    pine      low       13
